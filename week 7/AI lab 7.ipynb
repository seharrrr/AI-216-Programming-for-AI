# %% [markdown]
# Task no 1

# %%
import pandas as pd
import json

csv_data = """id,name,age,experience,expected_salary,education,city
1,Ali,22,1,40000,Bachelors,Islamabad
2,Sara,25,3,60000,Masters,Lahore
3,Ahmed,,5,?,Bachelors,Karachi
4,Ayesha,28,,80000,,isl
5,Hassan,30,7,90000,PhD,Peshawar
6,,19,0,45000,Bachelors,Islamabad
"""

with open("applicants.csv", "w") as f:
    f.write(csv_data)


json_data = [
    {"id": 1, "skills": ["python", "sql"], "status": "shortlisted"},
    {"id": 2, "skills": ["excel", "communication"], "status": "pending"},
    {"id": 3, "skills": None, "status": "rejected"},
    {"id": 4, "skills": ["python", "machine learning"], "status": "shortlisted"},
    {"id": 5, "skills": ["management"], "status": "pending"}
]

with open("applicants_extra.json", "w") as f:
    json.dump(json_data, f)

# %% [markdown]
# Task no 1

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler


df_csv = pd.read_csv("applicants.csv")
df_json = pd.read_json("applicants_extra.json")

print("CSV HEAD")
print(df_csv.head())

print("\nCSV TYPES")
print(df_csv.dtypes)

print("\nCSV MISSING")
print(df_csv.isnull().sum())

print("\nCSV SHAPE")
print(df_csv.shape)


print("\nJSON HEAD")
print(df_json.head())

print("\nJSON TYPES")
print(df_json.dtypes)

print("\nJSON MISSING")
print(df_json.isnull().sum())

print("\nJSON SHAPE")
print(df_json.shape)
# Out:
# CSV HEAD
#    id    name   age  experience expected_salary  education       city
# 0   1     Ali  22.0         1.0           40000  Bachelors  Islamabad
# 1   2    Sara  25.0         3.0           60000    Masters     Lahore
# 2   3   Ahmed   NaN         5.0               ?  Bachelors    Karachi
# 3   4  Ayesha  28.0         NaN           80000        NaN        isl
# 4   5  Hassan  30.0         7.0           90000        PhD   Peshawar
#
# CSV TYPES
# id                   int64
# name                object
# age                float64
# experience         float64
# expected_salary     object
# education           object
# city                object
# dtype: object
#
# CSV MISSING
# id                 0
# name               1
# age                1
# experience         1
# expected_salary    0
# education          1
# city               0
# dtype: int64
#
# CSV SHAPE
# (6, 7)
#
# JSON HEAD
#    id                      skills       status
# 0   1               [python, sql]  shortlisted
# 1   2      [excel, communication]      pending
# 2   3                        None     rejected
# 3   4  [python, machine learning]  shortlisted
# 4   5                [management]      pending
#
# JSON TYPES
# id         int64
# skills    object
# status    object
# dtype: object
#
# JSON MISSING
# id        0
# skills    1
# status    0
# dtype: int64
#
# JSON SHAPE
# (5, 3)

# %% [markdown]
# Task no 2

# %%
df = pd.merge(df_csv, df_json, on="id", how="left")


print(df)

print("\nShape:")
print(df.shape)
# Out:
#    id    name   age  experience expected_salary  education       city  \
# 0   1     Ali  22.0         1.0           40000  Bachelors  Islamabad
# 1   2    Sara  25.0         3.0           60000    Masters     Lahore
# 2   3   Ahmed   NaN         5.0               ?  Bachelors    Karachi
# 3   4  Ayesha  28.0         NaN           80000        NaN        isl
# 4   5  Hassan  30.0         7.0           90000        PhD   Peshawar
# 5   6     NaN  19.0         0.0           45000  Bachelors  Islamabad
#
#                        skills       status
# 0               [python, sql]  shortlisted
# 1      [excel, communication]      pending
# 2                        None     rejected
# 3  [python, machine learning]  shortlisted
# 4                [management]      pending
# 5                         NaN          NaN
#
# Shape:
# (6, 9)

# %% [markdown]
# Task no 3

# %%
df["age"] = df["age"].fillna(df["age"].median())


df["experience"] = df["experience"].fillna(0)



df["expected_salary"] = df["expected_salary"].replace("?", np.nan)


df["expected_salary"] = pd.to_numeric(df["expected_salary"])


df["expected_salary"] = df["expected_salary"].fillna(
    df["expected_salary"].median()
)



df["education"] = df["education"].fillna("Unknown")



df["name"] = df["name"].fillna("Unknown")


print(df.isnull().sum())
# Out:
# id                 0
# name               0
# age                0
# experience         0
# expected_salary    0
# education          0
# city               0
# skills             2
# status             1
# dtype: int64

# %% [markdown]
# Task no 4

# %%
df["city"] = df["city"].replace("isl", "Islamabad")

df["city"] = df["city"].str.lower()

print(df["city"].unique())
# Out:
# ['islamabad' 'lahore' 'karachi' 'peshawar']

# %% [markdown]
# Task no 5

# %%
def experience_level(exp):

    if exp <= 1:
        return "junior"

    elif exp <= 5:
        return "mid"

    else:
        return "senior"


df["experience_level"] = df["experience"].apply(experience_level)

print(df[["experience", "experience_level"]])
# Out:
#    experience experience_level
# 0         1.0           junior
# 1         3.0              mid
# 2         5.0              mid
# 3         0.0           junior
# 4         7.0           senior
# 5         0.0           junior

# %% [markdown]
# Task no 6

# %%
cols = ["age", "experience", "expected_salary"]

scaler = MinMaxScaler()

df[cols] = scaler.fit_transform(df[cols])

print(df[cols])
# Out:
#         age  experience  expected_salary
# 0  0.272727    0.142857              0.0
# 1  0.545455    0.428571              0.4
# 2  0.545455    0.714286              0.4
# 3  0.818182    0.000000              0.8
# 4  1.000000    1.000000              1.0
# 5  0.000000    0.000000              0.1

# %% [markdown]
# Task no 7

# %%
def preprocess_applicants(df):


    df["age"] = df["age"].fillna(df["age"].median())

    df["experience"] = df["experience"].fillna(0)

    df["expected_salary"] = df["expected_salary"].replace("?", np.nan)

    df["expected_salary"] = pd.to_numeric(df["expected_salary"])

    df["expected_salary"] = df["expected_salary"].fillna(
        df["expected_salary"].median()
    )

    df["education"] = df["education"].fillna("Unknown")

    df["name"] = df["name"].fillna("Unknown")


    df["city"] = df["city"].replace("isl", "Islamabad")

    df["city"] = df["city"].str.lower()


    def experience_level(exp):

        if exp <= 1:
            return "junior"

        elif exp <= 5:
            return "mid"

        else:
            return "senior"

    df["experience_level"] = df["experience"].apply(experience_level)



    cols = ["age", "experience", "expected_salary"]

    scaler = MinMaxScaler()

    df[cols] = scaler.fit_transform(df[cols])

    return df
